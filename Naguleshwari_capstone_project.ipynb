# %% [markdown]
# # CAPESTONE-PROJECT (PYTHON)

# %%
#Import the required libraries
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np                          # for numerical computation

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Task1:**

# %%
#Read the csv file 
df = pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
#Displaying  the number of rows and columns in the dataset.
df.shape
# Out:
# (4803, 20)

# %%
# Displaying the title and genres of the first 50 movies from the dataset.
df[["title","genres"]].head(50)
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# **Task2:**

# %%
# Identify the columns that have null values.
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# check the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
# homepage
mode_value = df["homepage"].mode()[0]

# Fill missing categorical object data type values with the mode value
df["homepage"].fillna(value=mode_value, inplace=True)

# %%
# tagline
mode_value = df["tagline"].mode()[0]

# Fill missing categorical object data type values with the mode value
df["tagline"].fillna(value=mode_value, inplace=True)

# %%
# Overview
mode_value = df["overview"].mode()[0]

# Fill missing categorical object data type values with the mode value
df["overview"].fillna(value=mode_value, inplace=True)

# %%
# release_data
mode_value = df["release_date"].mode()[0]

# Fill missing categorical object data type values with the mode value
df["release_date"].fillna(value=mode_value, inplace=True)

# %%
# runtime
mean_value = df["runtime"].mean()

# Fill missing Numerical object data type values with the mode value
df["runtime"].fillna(value=mean_value, inplace=True)

# %%
# Again check the null values are present or not
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# # **Task3:**

# %%
#Display the movie categories that have a budget greater than $220,000
filtered_Budget = df[df['budget'] > 220000]
filtered_Budget
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4680     450000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4682   13000000                     [{"id": 27, "name": "Horror"}]
# 4720    8500000                      [{"id": 18, "name": "Drama"}]
# 4758    4000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 4770     500000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # **Task4:**

# %%
#Display the movies category where the revenue is greater than 961,000,000.
filtered_Revenue = df[df['revenue'] > 961000000]
filtered_Revenue
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 12   200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17   380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 32   200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 36   210000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...

# %% [markdown]
# # **Task5:**

# %%
# Drop the rows which are having the 0 value present in the budget and revenue columns
data = df[(df['budget'] != 0) & (df['revenue'] != 0)]
data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # **Task6:**

# %%
#Top 10 movies with highest revenue
highest_revenue = df.sort_values(by='revenue', ascending=False)

# %%
 # pick Top 10 movies
highest_revenue.head(10)
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 25                         http://www.titanicmovie.com     597
# ...

# %%
#Top 10 movies with the least budget
least_budget = df.sort_values(by='budget', ascending=True)

# %%
least_budget.head(10)
# Out:
#       budget                                             genres  \
# 2401       0                   [{"id": 53, "name": "Thriller"}]
# 3187       0  [{"id": 35, "name": "Comedy"}, {"id": 10402, "...
# 3183       0  [{"id": 10749, "name": "Romance"}, {"id": 18, ...
# 3179       0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3178       0                      [{"id": 18, "name": "Drama"}]
# 3176       0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3157       0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3156       0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 3154       0  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 3152       0  [{"id": 18, "name": "Drama"}, {"id": 10752, "n...
#
#                                       homepage      id  \
# 2401         http://www.missionimpossible.com/   31932
# 3187         http://www.missionimpossible.com/   12621
# 3183         http://www.missionimpossible.com/   14624
# ...

# %% [markdown]
# # TASK7

# %%
# Display the correlation as a heatmap
data = df[['popularity', 'budget']]
correlation_matrix = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap Between Popularity and Budget')
plt.show()

# Print the correlation value
print(f"The correlation between popularity and budget is: {correlation}")
# Out:
# The correlation between popularity and budget is: 0.5054139990665322

# %%
fig,ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(),annot= True ,cmap="Blues_r", cbar = True,linewidth=0.3)
plt.show()

# %% [markdown]
# # TASK8

# %%
import json
# Convert the string representation of production companies into a list of dictionaries
df['production_companies'] = df['production_companies'].apply(lambda x: json.loads(x))

# %%
# # Initialize an empty dictionary to store production company names and their counts
production_counts = {}

# Iterate over each row in the DataFrame
for row in df.itertuples(index=False):
    # Iterate over each production company in the row
    for company in row.production_companies:
        # Extract the production company name
        company_name = company['name']
        
        # Increment the count for the production company
        if company_name in production_counts:
            production_counts[company_name] += 1
        else:
            production_counts[company_name] = 1

# Create a new DataFrame to store the production company names and their counts
production_df = pd.DataFrame({'Production Company': list(production_counts.keys()), 'Count': list(production_counts.values())})

# Sort the DataFrame by count in descending order
production_df = production_df.sort_values('Count', ascending=False)
production_df
# Out:
#                           Production Company  Count
# 11                              Warner Bros.    319
# 52                        Universal Pictures    311
# 38                        Paramount Pictures    285
# 1     Twentieth Century Fox Film Corporation    222
# 7                          Columbia Pictures    201
# ...                                      ...    ...
# 2323                         Greenlit Rights      1
# 2324                           Q Productions      1
# 2325                           Central Films      1
# 2326                   Goodspeed Productions      1
# 5016                        lucky crow films      1
#
# [5017 rows x 2 columns]

# %% [markdown]
# # TASK9

# %%
# Select the top 25 production companies
production_df = production_df.sort_values('Count', ascending=False)
production_df.head(25)
# Out:
#                           Production Company  Count
# 11                              Warner Bros.    319
# 52                        Universal Pictures    311
# 38                        Paramount Pictures    285
# 1     Twentieth Century Fox Film Corporation    222
# 7                          Columbia Pictures    201
# 46                           New Line Cinema    165
# 49                 Metro-Goldwyn-Mayer (MGM)    122
# 200                      Touchstone Pictures    118
# 4                       Walt Disney Pictures    114
# 54                          Relativity Media    102
# 257            Columbia Pictures Corporation     96
# 391                            Miramax Films     94
# 112                Village Roadshow Pictures     81
# 80                            DreamWorks SKG     79
# 532                           United Artists     75
# 370                                   Canal+     75
# 296                      Regency Enterprises     69
# ...

# %% [markdown]
# # TASK10

# %%
# Sort the data in descending order based on revenue and filter the top 500 movies
top_500_movies = df.nlargest(500, 'revenue')

# Calculate the measures of central tendency for budget, revenue, and runtime
budget_mean = top_500_movies['budget'].mean()
budget_median = top_500_movies['budget'].median()
budget_mode = top_500_movies['budget'].mode().values[0]

revenue_mean = top_500_movies['revenue'].mean()
revenue_median = top_500_movies['revenue'].median()
revenue_mode = top_500_movies['revenue'].mode().values[0]

runtime_mean = top_500_movies['runtime'].mean()
runtime_median = top_500_movies['runtime'].median()
runtime_mode = top_500_movies['runtime'].mode().values[0]

# Perform outlier analysis using box plots
plt.figure(figsize=(10, 6))
plt.subplot(1, 3, 1)
plt.boxplot(top_500_movies['budget'], vert=False)
plt.title('Budget Box Plot')

plt.subplot(1, 3, 2)
plt.boxplot(top_500_movies['revenue'], vert=False)
plt.title('Revenue Box Plot')

plt.subplot(1, 3, 3)
plt.boxplot(top_500_movies['runtime'], vert=False)
plt.title('Runtime Box Plot')

plt.show()

# Display the measures of central tendency
print(f"Budget Mean: {budget_mean}, Median: {budget_median}, Mode: {budget_mode}")
print(f"Revenue Mean: {revenue_mean}, Median: {revenue_median}, Mode: {revenue_mode}")
print(f"Runtime Mean: {runtime_mean}, Median: {runtime_median}, Mode: {runtime_mode}")
# Out:
# Budget Mean: 102803736.0, Median: 95000000.0, Mode: 150000000
# Revenue Mean: 458722133.294, Median: 363001569.5, Mode: 219076518
# Runtime Mean: 118.626, Median: 116.0, Mode: 115.0

# %% [markdown]
# # TASK11

# %%
# Calculate the average runtime
average_runtime = top_500_movies['runtime'].mean()

# Filter movies with runtimes above the average
above_average_runtime_movies = top_500_movies[top_500_movies['runtime'] > average_runtime]

# Create a DataFrame with movie names and runtimes
result_df = above_average_runtime_movies[['title','runtime']]

# Display the DataFrame
result_df
# Out:
#                            title  runtime
# 0                         Avatar    162.0
# 25                       Titanic    194.0
# 16                  The Avengers    143.0
# 28                Jurassic World    124.0
# 44                     Furious 7    137.0
# ...                          ...      ...
# 1161          The Social Network    120.0
# 912   Interview with the Vampire    123.0
# 521                 The Terminal    128.0
# 397             It's Complicated    121.0
# 1744                  Knocked Up    129.0
#
# [232 rows x 2 columns]
